# %% [markdown]
# # Titanic ML – Improved Preprocessing (Colab)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1b5S5wHqXlsQuX2oxqABmvkmSIrtJaygk?usp=sharing)
#
# This notebook contains the improved preprocessing & model tuning workflow.
