# %% [markdown]
# # Titanic ML – Baseline (Colab)
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/drive/1GBJfgZN4xxxZX7LPAjmtD1Sy_YR2L00O?usp=sharing)
#
# This notebook mirrors the baseline preprocessing/classification workflow for the Titanic dataset.
